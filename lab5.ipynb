# %%
from IPython.display import Markdown, display

text = """
# Лабораторна робота №5

**Виконав:** студент групи ОІ-32 Прокопів Юрій  
**Прийняла:** асистентка Нарушинська О.О.

### Тема:
Моніторинг моделі машинного навчання на основі виробничих та 
еталонних даних

### Мета: Навчитися будувати дашборди для моніторингу продуктивності 
ML-моделі, відстежувати зміни у вхідних даних, виявляти деградацію моделі та 
ознаки data drift, target drift, використовуючи Evidently AI

**Варіант – 7**
## Висновки

У результаті виконанння даної лабораторної роботи, було створено моніторинг машинного навчання використовуючи EvidentlyAI, це справді дуже важлива річ, і я повністю усвідомлюю її важливість,
АЛЕ встановлення цієї бібліотеки було найгіршими трьома годинами за моє життя, нова версія бібліотеки банально не працює з іншими бібліотеками/версію Python 3.14, відповідно треба було сидіти потіти годинами заради того щоб знайти які версії бібліотек треба було встановити,
в особливості проблеми були з бібліотекою Pydantic, а ще я поняття не маю як це взагалі можливо але чомусь версії пайтону 3.14 не існує в моїх файлах PATH, відповідно для реалізації, 
найлегшим рішенням було створення віртуального середовища версії python 3.12, а потім знову шукати версії Evidently, Pydantic, Numpy які будуть сумісні один з одною, сказати що я кричав від болі
це ще нічого не сказати, дякую за увагу!

"""

display(Markdown(text))
# Out:
# # Лабораторна робота №5
#
# **Виконав:** студент групи ОІ-32 Прокопів Юрій
# **Прийняла:** асистентка Нарушинська О.О.
#
# ### Тема:
# Моніторинг моделі машинного навчання на основі виробничих та
# еталонних даних
#
# ### Мета: Навчитися будувати дашборди для моніторингу продуктивності
# ML-моделі, відстежувати зміни у вхідних даних, виявляти деградацію моделі та
# ознаки data drift, target drift, використовуючи Evidently AI
#
# **Варіант – 7**
# ## Висновки
#
# У результаті виконанння даної лабораторної роботи, було створено моніторинг машинного навчання використовуючи EvidentlyAI, це справді дуже важлива річ, і я повністю усвідомлюю її важливість,
# АЛЕ встановлення цієї бібліотеки було найгіршими трьома годинами за моє життя, нова версія бібліотеки банально не працює з іншими бібліотеками/версію Python 3.14, відповідно треба було сидіти потіти годинами заради того щоб знайти які версії бібліотек треба було встановити,
# ...

# %% [markdown]
# ![cute-cat-standing.jpg](attachment:eb2cd150-8ded-4321-bd55-23cce1b5a614.jpg)
